# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
import cobra
from cobra.test import create_test_model
cobra_config = cobra.Configuration()
cobra_config.solver = "gurobi"
model = create_test_model("textbook")
model.solver

# %%
int_reactions3= list()
i= -1
r = a.reactions[0]
r_id = r.id
zero= list()
one= list()

for r in a.reactions:
    i= i+1
    r = a.reactions[i]
    r_id = r.id

    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}.csv'.format(r_id))
    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v == 1:
        one.append(r_id)
    elif v == 0:
        zero.append(r_id)

print(one)
print(zero)
# Out:
# ['EX_cm_e', 'EX_cobalt2_e', 'EX_colipa_e', 'EX_colipap_e', 'EX_crn_e', 'EX_crn__D_e', 'DM_4crsol_c', 'EX_cu2_e', 'DM_5drib_c', 'EX_cyan_e', 'DM_aacald_c', 'DM_amob_c', 'DM_mththf_c', 'EX_glyb_e', 'EX_gthox_e', 'BIOMASS_Ec_iJO1366_WT_53p95M', 'BIOMASS_Ec_iJO1366_core_53p95M', 'EX_14glucan_e', 'EX_15dap_e', 'EX_h2o2_e', 'EX_hacolipa_e', 'EX_halipa_e', 'EX_34dhpac_e', 'EX_hg2_e', 'EX_his__L_e', 'EX_4hoxpacd_e', 'EX_5mtr_e', 'EX_cys__D_e', 'EX_ile__L_e', 'EX_acgal_e', 'EX_inost_e', 'EX_k_e', 'EX_kdo2lipid4_e', 'EX_acolipa_e', 'EX_adocbl_e', 'EX_leu__L_e', 'EX_lipa_e', 'EX_lipa_cold_e', 'EX_ag_e', 'EX_lipoate_e', 'EX_ala_B_e', 'EX_malthx_e', 'EX_maltpt_e', 'EX_malttr_e', 'EX_maltttr_e', 'EX_arbt_e', 'EX_meoh_e', 'EX_met__D_e', 'EX_aso3_e', 'EX_met__L_e', 'EX_metsox_R__L_e', 'EX_metsox_S__L_e', 'EX_mg2_e', 'EX_mincyc_e', 'EX_btn_e', 'EX_mmet_e', 'EX_mn2_e', 'EX_ca2_e', 'EX_cbi_e', 'EX_mobd_e', 'EX_n2o_e', 'EX_na1_e', 'EX_nac_e', 'EX_cbl1_e', 'EX_cd2_e', 'EX_chol_e', 'EX_cl_e', 'EX_ni2_e', 'EX_nmn_e', 'EX_dms_e', 'EX_novbcn_e', 'EX_o16a4colipa_e', 'EX_doxrbcn_e', 'EX_o2s_e', 'EX_xtsn_e', 'EX_pacald_e', 'EX_zn2_e', '12DGR120tipp', '12DGR140tipp', '12DGR141tipp', '12DGR160tipp', 'EX_phe__L_e', 'EX_pheme_e', 'EX_pnto__R_e', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', '14GLUCANtexi', 'EX_eca4colipa_e', '23CAMPtex', '23CCMPtex', 'EX_pydam_e', '23CGMPtex', '23CUMPtex', '23DAPPAt2pp', '23DAPPAtex', '23PDE2pp', '23PDE4pp', 'EX_pydx_e', 'EX_pydxn_e', 'EX_rfamp_e', '23PDE7pp', '23PDE9pp', 'EX_enlipa_e', 'EX_sel_e', '26DAHtex', 'EX_slnt_e', 'EX_so2_e', 'EX_so3_e', 'EX_spmd_e', 'EX_tcynt_e', 'EX_thm_e', 'EX_tma_e', 'EX_tsul_e', 'EX_ttrcyc_e', 'EX_tungs_e', 'EX_tyr__L_e', '34dhpactex', '3GMPtex', '3AMPtex', '3CMPtex', 'EX_fuc__L_e', '3HAD40', '3HAD60', '3HAD80', '3HCINNMH', 'AADDGT', 'AAMYLpp', '3HPPPNH', '3KGK', 'AB6PGH', '3NTD2pp', '3NTD4pp', '3NTD7pp', 'EX_fusa_e', '3NTD9pp', '3OAR40', 'ACACt2pp', 'ACACtex', '3OAR60', '3OAR80', 'ACANTHAT', 'ACBIPGT', '3OAS60', 'ACGAL1PPpp', 'ACGAL1Ptex', 'ACGALtex', 'ACGAM1PPpp', 'ACGAM1Ptex', 'ACGAMT', '3OAS80', '3PEPTtex', '3UMPtex', '42A12BOOXpp', 'ACGAptspp', 'ACGAtex', '4HOXPACDtex', '4HTHRS', 'ACHBS', 'ACMAMUT', '4PEPTtex', 'ACMANAptspp', 'ACMANAtex', 'ACMUMptspp', 'ACMUMtex', 'ACNAMt2pp', '5DOAN', '5MTRtex', '5MTRtpp', 'A5PISO', 'ACNAMtex', 'ACNML', 'ACOAD1f', 'ACOAD2f', 'ACOAD3f', 'ACONIs', 'ACONMT', 'AGt3', 'AHCYSNS', 'ACPS1', 'ALAALAtex', 'ADCL', 'ADCS', 'ALATRS', 'ADMDC', 'ADNt2pp', 'ALDD4', 'ADNtex', 'EX_gbbtn_e', 'ADOCBIK', 'ADOCBLS', 'ADOCBLabcpp', 'ADOCBLtonex', 'ALLK', 'ALLPI', 'ALLULPE', 'ALLabcpp', 'EX_gdp_e', 'ALLtex', 'ANS', 'ALTRH', 'AMALT1', 'AMANAPEr', 'AMANK', 'AGMHE', 'AGMtex', 'AMAOTr', 'AMMQLT8', 'AMPMS2', 'AMPTASEPG', 'AMPtex', 'AOXSr2', 'ANHGMtex', 'ANPRT', 'AP5AH', 'ASPTRS', 'APCS', 'ASR', 'CDGR', 'CDGS', 'CDPMEK', 'CFAS160E', 'CFAS160G', 'CFAS180E', 'ATPPRT', 'BALAtex', 'CFAS180G', 'CGLYtex', 'CHLtex', 'BMOCOS', 'BMOGDS1', 'BMOGDS2', 'CHOLD', 'CHORM', 'BTNt2ipp', 'BTNtex', 'BTS5', 'CHORS', 'CHRPL', 'CHTBSptspp', 'CHTBStex', 'BUTSO3abcpp', 'CINNDO', 'BUTSO3tex', 'BUTt2rpp', 'BUTtex', 'BWCOGDS1', 'BWCOGDS2', 'BWCOS', 'CA2tex', 'CADVtpp', 'CBIAT', 'CBItonex', 'CBIuabcpp', 'CBL1abcpp', 'CBL1tonex', 'CBLAT', 'CLt3_2pp', 'CLtex', 'CMPtex', 'CCGS', 'CD2tex', 'COBALT2tex', 'APPLDHr', 'COLIPAKpp', 'COLIPAPabctex', 'COLIPAabcpp', 'APRAUR', 'CPMPS', 'CPPPGO', 'CPPPGO2', 'CRNBTCT', 'CRNCAR', 'CRNCBCT', 'ARAI', 'CRNCDH', 'CRNDCAL2', 'CPH4S', 'CRNDtex', 'CRNt7pp', 'DADNt2pp', 'CRNtex', 'DADNtex', 'CSNtex', 'DAMPtex', 'DAPAL', 'DAPDC', 'DAPE', 'DAPabcpp', 'DAPtex', 'CU2tex', 'DB4PS', 'DBTS', 'CUtex', 'CYANST', 'CYANSTpp', 'CYANtex', 'CYNTAH', 'CYNTt2pp', 'DC6PH', 'DCAtex', 'DCMPtex', 'CYNTtex', 'DCYTt2pp', 'DCYTtex', 'DDCAtexi', 'DDGALK', 'CYSDabcpp', 'CYSDtex', 'CYSSADS', 'DDGLCNt2rpp', 'DDGLCNtex', 'CYSTL', 'CYSTRS', 'DDPA', 'DDPGALA', 'DGMPtex', 'DGSNt2pp', 'DGSNtex', 'DHAD2', 'ARBTptspp', 'CYTDt2pp', 'CYTDtex', 'ARBTtex', 'DHBD', 'DHCIND', 'DHCINDO', 'DHDPRy', 'DHQTi', 'DHDPS', 'DHFS',  ...
# []

# %%
D= pd.DataFrame (one, columns = ['1 feasible value'])
D
# Out:
#      1 feasible value
# 0             EX_cm_e
# 1        EX_cobalt2_e
# 2         EX_colipa_e
# 3        EX_colipap_e
# 4            EX_crn_e
# ...               ...
# 1110            AMID3
# 1111             SUCP
# 1112          LTARTDH
# 1113           UAG4Ei
# 1114          UGCIAMH
#
# [1115 rows x 1 columns]

# %%
fl= list()
diff= list()
i= 0
r = a.reactions[0]

for r in a.reactions:

    n= 0
    r = a.reactions[i]
    r_id = r.id
    l= list()
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])
        l
        n= n+1
    
    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v>1:
        d= pd.DataFrame (l, columns = ['Biomass'])
        
    
        if len(np.unique(d.Biomass)) == 1:
            fl.append(r_id)
        else:
            diff.append(r_id)
    
    i= i+1
        
print(fl)
print(diff)
# Out:
# ['EX_cpgn_un_e', 'EX_arbtn_e', 'EX_enter_e', 'EX_fe3hox_un_e', 'EX_fecrm_un_e', 'EX_feoxam_un_e', 'ACLS', 'AMALT3', 'DHAD1', 'GLBRAN2', 'ICHORS_copy1', 'HPYRI', 'KARA1', 'THFAT', 'DARBt2rpp_copy1']
# ['EX_cmp_e', 'EX_co2_e', 'EX_cpgn_e', 'EX_csn_e', 'EX_glc__D_e', 'EX_glcn_e', 'EX_cu_e', 'EX_glcr_e', 'EX_glcur_e', 'EX_glcur1p_e', 'EX_gln__L_e', 'EX_glu__L_e', 'DM_oxam_c', 'EX_gly_e', 'EX_glyald_e', 'EX_glyc_e', 'EX_glyc__R_e', 'EX_glyc2p_e', 'EX_glyc3p_e', 'EX_glyclt_e', 'EX_gmp_e', 'EX_gsn_e', 'EX_gthrd_e', 'EX_gtp_e', 'EX_gua_e', 'EX_h_e', 'EX_h2_e', 'EX_h2o_e', 'EX_12ppd__R_e', 'EX_12ppd__S_e', 'EX_23camp_e', 'EX_23ccmp_e', 'EX_23cgmp_e', 'EX_23cump_e', 'EX_23dappa_e', 'EX_26dap__M_e', 'EX_2ddglcn_e', 'EX_h2s_e', 'EX_hdca_e', 'EX_3amp_e', 'EX_hdcea_e', 'EX_3cmp_e', 'EX_cynt_e', 'EX_3gmp_e', 'EX_3hcinnm_e', 'EX_3hpp_e', 'EX_3hpppn_e', 'EX_3ump_e', 'EX_4abut_e', 'EX_hom__L_e', 'EX_hxa_e', 'EX_hxan_e', 'EX_5dglcn_e', 'EX_LalaDglu_e', 'EX_LalaDgluMdap_e', 'EX_cys__L_e', 'EX_LalaDgluMdapDala_e', 'EX_cytd_e', 'EX_LalaLglu_e', 'EX_ac_e', 'EX_idon__L_e', 'EX_dad_2_e', 'EX_imp_e', 'EX_indole_e', 'EX_acac_e', 'EX_acald_e', 'EX_damp_e', 'EX_ins_e', 'EX_isetac_e', 'EX_acgal1p_e', 'EX_acgam_e', 'EX_acgam1p_e', 'EX_acmana_e', 'EX_acmum_e', 'EX_acnam_e', 'EX_lac__D_e', 'EX_lac__L_e', 'EX_lcts_e', 'EX_acser_e', 'EX_dca_e', 'EX_ade_e', 'EX_adn_e', 'EX_dcmp_e', 'EX_agm_e', 'EX_dcyt_e', 'EX_lys__L_e', 'EX_lyx__L_e', 'EX_akg_e', 'EX_ala__D_e', 'EX_mal__D_e', 'EX_ala__L_e', 'EX_mal__L_e', 'EX_ddca_e', 'EX_malt_e', 'EX_alaala_e', 'EX_all__D_e', 'EX_alltn_e', 'EX_dgmp_e', 'EX_man_e', 'EX_man6p_e', 'EX_manglyc_e', 'EX_amp_e', 'EX_anhgm_e', 'EX_arab__L_e', 'EX_melib_e', 'EX_arbtn_fe3_e', 'EX_arg__L_e', 'EX_dgsn_e', 'EX_ascb__L_e', 'EX_asn__L_e', 'EX_asp__L_e', 'EX_dha_e', 'EX_but_e', 'EX_minohp_e', 'EX_butso3_e', 'EX_dimp_e', 'EX_mnl_e', 'EX_mso3_e', 'EX_din_e', 'EX_nh4_e', 'EX_cgly_e', 'EX_chtbs_e', 'EX_cit_e', 'EX_no_e', 'EX_no2_e', 'EX_dmso_e', 'EX_no3_e', 'EX_dopa_e', 'EX_o2_e', 'EX_val__L_e', 'EX_dtmp_e', 'EX_xan_e', 'EX_ocdca_e', 'EX_ocdcea_e', 'EX_octa_e', 'EX_xmp_e', 'EX_orn_e', 'EX_dump_e', 'EX_orot_e', 'EX_xyl__D_e', 'EX_xylu__L_e', 'EX_peamn_e', 'EX_pi_e', 'EX_ppa_e', 'EX_ppal_e', 'EX_pppn_e', '12PPDRtex', 'EX_duri_e', '12PPDRtpp', '12PPDStex', '12PPDStpp', 'EX_ppt_e', 'EX_pro__L_e', 'EX_progly_e', 'EX_psclys_e', 'EX_pser__L_e', 'EX_ptrc_e', 'EX_pyr_e', 'EX_quin_e', 'EX_r5p_e', 'EX_rib__D_e', 'EX_rmn_e', 'EX_sbt__D_e', 'EX_ser__D_e', '2AGPA120tipp', '2AGPA140tipp', '2AGPA141tipp', 'EX_ser__L_e', 'EX_skm_e', '2AGPA160tipp', '2AGPA161tipp', 'EX_etha_e', '2AGPA180tipp', '2AGPA181tipp', '2AGPE120tipp', 'EX_ethso3_e', '2AGPE140tipp', '2AGPE141tipp', 'EX_so4_e', 'EX_succ_e', 'EX_sucr_e', 'EX_sulfac_e', 'EX_etoh_e', 'EX_tartr__D_e', 'EX_tartr__L_e', 'EX_f6p_e', 'EX_taur_e', '2AGPE160tipp', '2AGPE161tipp', '2AGPE180tipp', '2AGPE181tipp', 'EX_thr__L_e', 'EX_fald_e', 'EX_thrp_e', 'EX_thym_e', '2AGPEAT120', '2AGPEAT140', 'EX_thymd_e', 'EX_fe2_e', '2AGPEAT141', '2AGPEAT160', 'EX_tmao_e', '2AGPEAT161', 'EX_fe3_e', '2AGPEAT180', 'EX_tre_e', 'EX_trp__L_e', 'EX_ttdca_e', 'EX_ttdcea_e', '2AGPEAT181', '2AGPG120tipp', '2AGPG140tipp', '2AGPG141tipp', '2AGPG160tipp', '2AGPG161tipp', 'EX_tym_e', '2AGPG180tipp', 'EX_fe3dcit_e', '2AGPG181tipp', '2AGPGAT120', 'EX_tyrp_e', 'EX_uacgam_e', 'EX_udpacgal_e', '2AGPGAT140', '2AGPGAT141', 'EX_udpg_e', 'EX_udpgal_e', '2AGPGAT160', 'EX_fe3dhbzs_e', '2AGPGAT161', '2AGPGAT180', '2AGPGAT181', '2DGULRGx', 'EX_udpglcur_e', 'EX_ump_e', 'EX_ura_e', 'EX_fe3hox_e', 'EX_urea_e', 'EX_uri_e', '2DGULRGy', '2DGULRx', '2DGULRy', '2MAHMP', '3HAD100', '3AMACHYD', '3HAD120', '3HAD121', 'EX_fecrm_e', '3HAD140', 'EX_feenter_e', 'EX_feoxam_e', 'EX_for_e', 'EX_fru_e', 'EX_frulys_e', '3HAD141', 'EX_fruur_e', '3HAD160', '3HAD161', 'AACPS5', 'AACPS6', 'AACPS7', 'AACPS8', '3HAD180', '3HAD181', 'AACPS9', 'AACTOOR', '3HPPtex', 'EX_fum_e', '3HPPtpp', 'ABTA', 'ABUTD', 'ABUTt2pp', 'ABUTtex', '3OAR100', 'ACACCT', 'ACACT1r', '3OAR120', 'EX_g1p_e', '3OAR121', '3OAR140', 'ACACT2r', 'ACACT3r', 'EX_g3pc_e', 'ACACT4r', 'ACACT5r', '3OAR141', '3OAR160', '3OAR161', '3OAR180', '3OAR181', 'ACACT6r', 'ACACT7r', 'ACACT8r_copy1', 'ACALD', '3OAS100', 'ACALDtex', ' ...

# %%
i= 0
r = a.reactions[0]
flat= list()

for r in a.reactions:
    
    r = a.reactions[i]
    n=0
    n3=0
    count=0
    l= list()
    r_id= r.id
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])

        n= n+1


    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v>1:
        d= pd.DataFrame (l, columns = ['Biomass'])

        while n3 < len(d):

            if d.iloc[n3,  0] > max(d["Biomass"])-0.02 and d.iloc[n3,  0] < max(d["Biomass"])+0.02:
                count= count+1
    
            n3= n3+1
        
        if count> 0.95*len(d):
            flat.append(r.id)

    i= i+1

flat
# Out:
# ['EX_cpgn_un_e',
#  'EX_cu_e',
#  'EX_gtp_e',
#  'EX_acgal1p_e',
#  'EX_lys__L_e',
#  'EX_arbtn_e',
#  'EX_minohp_e',
#  'EX_dopa_e',
#  'EX_xmp_e',
#  'EX_peamn_e',
#  'EX_enter_e',
#  'EX_tym_e',
#  'EX_tyrp_e',
#  '2DGULRGy',
#  '2DGULRx',
#  '2DGULRy',
#  'EX_fe3hox_un_e',
#  'EX_fecrm_un_e',
#  'EX_feoxam_un_e',
#  'ABUTt2pp',
#  'ACACT1r',
#  'ACACT2r',
#  'ACACT3r',
#  'ACACT4r',
#  'ACACT5r',
#  'ACACT6r',
#  'ACACT7r',
#  'ACACT8r_copy1',
#  'ACCOAL',
#  'ACLS',
#  'ACS',
#  'ACt2rpp',
#  'ACt4pp',
#  'ALATA_L',
#  'ALAt2pp_copy1',
#  'ALAt2pp_copy2',
#  'ALAt4pp',
#  'ADK1',
#  'ADK3',
#  'ALDD19xr_copy1',
#  'AMALT2',
#  'AMALT3',
#  'AMALT4',
#  'ASPt2pp_copy1',
#  'BETALDHx',
#  'BSORy',
#  'CA2t3pp',
#  'CAt6pp',
#  'CRNCAL2',
#  'CRNt2rpp',
#  'CRNt8pp',
#  'CTBTCAL2',
#  'CTECOAI6_copy1',
#  'CTECOAI7_copy1',
#  'CTECOAI8_copy1',
#  'CU1Opp',
#  'DHAD1',
#  'DAAD',
#  'DHNPA2r_copy1',
#  'DHORD2',
#  'DHORDfum',
#  'DKGLCNR2x',
#  'DKGLCNR2y',
#  'DMPPS',
#  'EAR40y',
#  'EAR60y',
#  'EAR80y',
#  'DSBAO1',
#  'EAR100y',
#  'EAR120y',
#  'EAR121y',
#  'EAR140y',
#  'EAR141y',
#  'EAR160y',
#  'EAR161y',
#  'EAR180y',
#  'EAR181y',
#  'FADRx2',
#  'FLVR',
#  'FMNRx2',
#  'FOMETRi',
#  'GLBRAN2',
#  'GLCP',
#  'GLCP2',
#  'GLCS1',
#  'GLCtex_copy1',
#  'GLCtex_copy2',
#  'GLDBRAN2',
#  'GLGC',
#  'GLUABUTt7pp',
#  'GLUt2rpp',
#  'GLUt4pp',
#  'GLYCK',
#  'GLYCLTt2rpp',
#  'GLYCLTt4pp',
#  'HACD1',
#  'HYD1pp',
#  'HACD2',
#  'HACD3',
#  'HACD4',
#  'HACD5',
#  'HACD6',
#  'HACD7',
#  'HACD8',
#  'ICHORS_copy1',
#  'ICHORS_copy2',
#  'INDOLEt2pp',
#  'INDOLEt2rpp',
#  'IPDPS',
#  'HPYRI',
#  'HPYRRx',
#  'KARA1',
#  'KAS14',
#  'KAS15',
#  'GLYt2pp_copy1',
#  'GLYt2pp_copy2',
#  'GLYt4pp',
#  'L_LACtex_copy1',
#  'MDDCP3pp',
#  'MECDPDH5',
#  'MLDCP2App',
#  'NO3R2pp',
#  'NAt3pp',
#  'NDPK1',
#  'NODOy',
#  'NHFRBO',
#  'NMNt7pp',
#  'OCTNLL',
#  'PDX5PO2',
#  'PDX5POi',
#  'PROt2rpp',
#  'PROt4pp',
#  'QMO3',
#  'R15BPK',
#  'R1PK',
#  'SSALx',
#  'SERt2rpp',
#  'SERt4pp',
#  'THFAT',
#  'THRA',
#  'THRD',
#  'TRPS1',
#  'TRSARr',
#  'URAt2pp_copy1',
#  'URAt2pp_copy2',
#  'VPAMTr_copy1',
#  'VALTA',
#  'L_LACtex_copy2',
#  'MICITDr_copy2',
#  'NPHS',
#  'CTECOAI8_copy2',
#  'CTECOAI6_copy2',
#  'VPAMTr_copy2',
#  'PPCSCT',
#  '2DGLCNRy',
#  'ALDD19xr_copy2',
#  'DHNPA2r_copy2',
#  'HACD1i',
#  'HACD2i',
#  'HACD3i',
#  'HACD4i',
#  'HACD5i',
#  'DARBt2rpp_copy1',
#  'HACD6i',
#  'HACD7i',
#  'DARBt2rpp_copy2',
#  'HACD8i',
#  'CTECOAI7_copy2',
#  'KAT1',
#  'ACACT11',
#  'ACACT8',
#  'ACACT13',
#  'ACACT10',
#  'ACACT9',
#  'ACACT12',
#  'ACACT8r_copy2',
#  'DOGULND']

# %%
i= 0
r = a.reactions[0]
n=0
n3=0
count=0
l= list()
fl= list()
r_id= "VALTA"

while n < 201:
    inf= csvFile.iloc[n,  2]
    flt= float(csvFile.iloc[n,  2])
    
    if csvFile.iloc[n,  2] == flt:
        l.append(csvFile.iloc[n,  2])

    n= n+1


v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
if v>1:
    d= pd.DataFrame (l, columns = ['Biomass'])

while n3 < len(d):

    if d.iloc[n3,  0] > max(d["Biomass"])-0.02 and d.iloc[n3,  0] < max(d["Biomass"])+0.02:
        count= count+1
    
    n3= n3+1

if count> 0.95*len(d):
    fl.append(r_id)

fl
# Out:
# []

# %%
i= 0
r = a.reactions[0]
flat= list()
diff= list()

for r in a.reactions:
    
    r = a.reactions[i]
    n=0
    n3=0
    count=0
    l= list()
    r_id= r.id
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])

        n= n+1


    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v>1:
        d= pd.DataFrame (l, columns = ['Biomass'])

        while n3 < len(d):

            if d.iloc[n3,  0] > max(d["Biomass"])-0.02 and d.iloc[n3,  0] < max(d["Biomass"])+0.02:
                count= count+1
    
            n3= n3+1
        
        if count> 0.95*len(d):
            flat.append(r_id)
        else:
            diff.append(r_id)

    i= i+1

flat
diff
# Out:
# ['EX_cmp_e',
#  'EX_co2_e',
#  'EX_cpgn_e',
#  'EX_csn_e',
#  'EX_glc__D_e',
#  'EX_glcn_e',
#  'EX_glcr_e',
#  'EX_glcur_e',
#  'EX_glcur1p_e',
#  'EX_gln__L_e',
#  'EX_glu__L_e',
#  'DM_oxam_c',
#  'EX_gly_e',
#  'EX_glyald_e',
#  'EX_glyc_e',
#  'EX_glyc__R_e',
#  'EX_glyc2p_e',
#  'EX_glyc3p_e',
#  'EX_glyclt_e',
#  'EX_gmp_e',
#  'EX_gsn_e',
#  'EX_gthrd_e',
#  'EX_gua_e',
#  'EX_h_e',
#  'EX_h2_e',
#  'EX_h2o_e',
#  'EX_12ppd__R_e',
#  'EX_12ppd__S_e',
#  'EX_23camp_e',
#  'EX_23ccmp_e',
#  'EX_23cgmp_e',
#  'EX_23cump_e',
#  'EX_23dappa_e',
#  'EX_26dap__M_e',
#  'EX_2ddglcn_e',
#  'EX_h2s_e',
#  'EX_hdca_e',
#  'EX_3amp_e',
#  'EX_hdcea_e',
#  'EX_3cmp_e',
#  'EX_cynt_e',
#  'EX_3gmp_e',
#  'EX_3hcinnm_e',
#  'EX_3hpp_e',
#  'EX_3hpppn_e',
#  'EX_3ump_e',
#  'EX_4abut_e',
#  'EX_hom__L_e',
#  'EX_hxa_e',
#  'EX_hxan_e',
#  'EX_5dglcn_e',
#  'EX_LalaDglu_e',
#  'EX_LalaDgluMdap_e',
#  'EX_cys__L_e',
#  'EX_LalaDgluMdapDala_e',
#  'EX_cytd_e',
#  'EX_LalaLglu_e',
#  'EX_ac_e',
#  'EX_idon__L_e',
#  'EX_dad_2_e',
#  'EX_imp_e',
#  'EX_indole_e',
#  'EX_acac_e',
#  'EX_acald_e',
#  'EX_damp_e',
#  'EX_ins_e',
#  'EX_isetac_e',
#  'EX_acgam_e',
#  'EX_acgam1p_e',
#  'EX_acmana_e',
#  'EX_acmum_e',
#  'EX_acnam_e',
#  'EX_lac__D_e',
#  'EX_lac__L_e',
#  'EX_lcts_e',
#  'EX_acser_e',
#  'EX_dca_e',
#  'EX_ade_e',
#  'EX_adn_e',
#  'EX_dcmp_e',
#  'EX_agm_e',
#  'EX_dcyt_e',
#  'EX_lyx__L_e',
#  'EX_akg_e',
#  'EX_ala__D_e',
#  'EX_mal__D_e',
#  'EX_ala__L_e',
#  'EX_mal__L_e',
#  'EX_ddca_e',
#  'EX_malt_e',
#  'EX_alaala_e',
#  'EX_all__D_e',
#  'EX_alltn_e',
#  'EX_dgmp_e',
#  'EX_man_e',
#  'EX_man6p_e',
#  'EX_manglyc_e',
#  'EX_amp_e',
#  'EX_anhgm_e',
#  'EX_arab__L_e',
#  'EX_melib_e',
#  'EX_arbtn_fe3_e',
#  'EX_arg__L_e',
#  'EX_dgsn_e',
#  'EX_ascb__L_e',
#  'EX_asn__L_e',
#  'EX_asp__L_e',
#  'EX_dha_e',
#  'EX_but_e',
#  'EX_butso3_e',
#  'EX_dimp_e',
#  'EX_mnl_e',
#  'EX_mso3_e',
#  'EX_din_e',
#  'EX_nh4_e',
#  'EX_cgly_e',
#  'EX_chtbs_e',
#  'EX_cit_e',
#  'EX_no_e',
#  'EX_no2_e',
#  'EX_dmso_e',
#  'EX_no3_e',
#  'EX_o2_e',
#  'EX_val__L_e',
#  'EX_dtmp_e',
#  'EX_xan_e',
#  'EX_ocdca_e',
#  'EX_ocdcea_e',
#  'EX_octa_e',
#  'EX_orn_e',
#  'EX_dump_e',
#  'EX_orot_e',
#  'EX_xyl__D_e',
#  'EX_xylu__L_e',
#  'EX_pi_e',
#  'EX_ppa_e',
#  'EX_ppal_e',
#  'EX_pppn_e',
#  '12PPDRtex',
#  'EX_duri_e',
#  '12PPDRtpp',
#  '12PPDStex',
#  '12PPDStpp',
#  'EX_ppt_e',
#  'EX_pro__L_e',
#  'EX_progly_e',
#  'EX_psclys_e',
#  'EX_pser__L_e',
#  'EX_ptrc_e',
#  'EX_pyr_e',
#  'EX_quin_e',
#  'EX_r5p_e',
#  'EX_rib__D_e',
#  'EX_rmn_e',
#  'EX_sbt__D_e',
#  'EX_ser__D_e',
#  '2AGPA120tipp',
#  '2AGPA140tipp',
#  '2AGPA141tipp',
#  'EX_ser__L_e',
#  'EX_skm_e',
#  '2AGPA160tipp',
#  '2AGPA161tipp',
#  'EX_etha_e',
#  '2AGPA180tipp',
#  '2AGPA181tipp',
#  '2AGPE120tipp',
#  'EX_ethso3_e',
#  '2AGPE140tipp',
#  '2AGPE141tipp',
#  'EX_so4_e',
#  'EX_succ_e',
#  'EX_sucr_e',
#  'EX_sulfac_e',
#  'EX_etoh_e',
#  'EX_tartr__D_e',
#  'EX_tartr__L_e',
#  'EX_f6p_e',
#  'EX_taur_e',
#  '2AGPE160tipp',
#  '2AGPE161tipp',
#  '2AGPE180tipp',
#  '2AGPE181tipp',
#  'EX_thr__L_e',
#  'EX_fald_e',
#  'EX_thrp_e',
#  'EX_thym_e',
#  '2AGPEAT120',
#  '2AGPEAT140',
#  'EX_thymd_e',
#  'EX_fe2_e',
#  '2AGPEAT141',
#  '2AGPEAT160',
#  'EX_tmao_e',
#  '2AGPEAT161',
#  'EX_fe3_e',
#  '2AGPEAT180',
#  'EX_tre_e',
#  'EX_trp__L_e',
#  'EX_ttdca_e',
#  'EX_ttdcea_e',
#  '2AGPEAT181',
#  '2AGPG120tipp',
#  '2AGPG140tipp',
#  '2AGPG141tipp',
#  '2AGPG160tipp',
#  '2AGPG161tipp',
#  '2AGPG180tipp',
#  'EX_fe3dcit_e',
#  '2AGPG181tipp',
#  '2AGPGAT120',
#  'EX_uacgam_e',
#  'EX_udpacgal_e',
#  '2AGPGAT140',
#  '2AGPGAT141',
#  'EX_udpg_e',
#  'EX_udpgal_e',
#  '2AGPGAT160',
#  'EX_fe3dhbzs_e',
#  '2AGPGAT161',
#  '2AGPGAT180',
#  '2AGPGAT181',
#  '2DGULRGx',
#  'EX_udpglcur_e',
#  'EX_ump_e',
#  'EX_ura_e',
#  'EX_fe3hox_e',
#  'EX_urea_e',
#  'EX_uri_e',
#  '2MAHMP',
#  '3HAD100',
#  '3AMACHYD',
#  '3HAD120',
#  '3HAD121',
#  'EX_fecrm_e',
#  '3HAD140',
#  'EX_feenter_e',
#  'EX_feoxam_e',
#  'EX_for_e',
#  'EX_fru_e',
#  'EX_frulys_e',
#  '3HAD141',
#  'EX_fruur_e',
#  '3HAD160',
#  '3HAD161',
#  'AACPS5',
#  'AACPS6',
#  'AACPS7',
#  'AACPS8',
#  '3HAD180',
#  '3HAD181',
#  'AACPS9',
#  'AACTOOR',
#  '3HPPtex',
#  'EX_fum_e',
#  '3HPPtpp',
#  'ABTA',
#  'ABUTD',
#  'ABUTtex',
#  '3OAR100',
#  'ACACCT',
#  '3OAR120',
#  'EX_g1p_e',
#  '3OAR121',
#  '3OAR140',
#  'EX_g3pc_e',
#  '3OAR141',
#  '3OAR160',
#  '3OAR161',
#  '3OAR180',
#  '3OAR181',
#  'ACALD',
#  '3OAS100',
#  'ACALDtex',
#  'ACALDtpp',
#  '3OAS120',
#  '3OAS121',
#  'EX_g3pe_e',
#  '3OAS140',
#  '3OAS141',
#  '3OAS160',
#  'ACCOAC',
#  '3OAS161',
#  'EX_g3pg_e',
#  '3OAS180',
#  '3OAS181',
#  'ACGAMK',
#  '3PEPTabcpp',
#  'EX_g3pi_e',
#  '4PCP',
#  'ACGK',
#  'ACGS',
#  'ACKr',
#  '4PCPpp',
#  '4PEPTabcpp',
#  'ACM6PH',
#  'EX_g3ps_e',
#  '5DGLCNR',
#  '5DGLCNt2rpp',
#  'EX_g6p_e',
#  '5DGLCNtex',
#  'AACPS1',
#  'EX_gal_e',
#  'AACPS2',
#  'AACPS3',
#  'AACPS4',
#  'EX_gal_bD_e',
#  'ACOAD4f',
#  'ACOAD5f',
#  'ACOATA',
#  'EX_gal1p_e',
#  'ACODA',
#  'ACOAD6f',
#  'ACOAD7f',
#  'ACOAD8f',
#  'ACOLIPAabctex',
#  'EX_galct__D_e',
#  'EX_galctn__D_e',
#  'ACONTa',
#  'ACONTb',
#  'ACOTA',
#  'ACPPAT120',
#  'ACPPAT140',
#  'ACPPAT141',
#  'AGPAT181',
#  'AGPR',
#  'AICART',
#  'AIRC2',
#  'ACPPAT160',
#  'ACPPAT161',
#  'ACPPAT180',
#  'AIRC3',
#  'EX_galctn__L_e',
#  'AKGDH',
#  'AKGt2rpp',
#  'AKGtex',
#  'ACPPAT181',
#  'ALAALAD',
#  'ACSERtex',
#  'EX_galt_e',
#  'ACSERtpp',
#  'ALAALAabcpp',
#  'ALAALAr',
#  'EX_galur_e',
#  'ACtex',
#  'ADA',
#  'ADD',
#  'ALAGLUE',
#  'ALAR',
#  'ALATA_D2',
#  'ALATA_L2',
#  'ALAabcpp',
#  'ADEt2rpp',
#  'ADEtex',
#  'EX_gam_e',
#  'ADK4',
#  'ALAtex',
#  'ALCD19',
#  'ALCD2x',
#  'ALDD2x',
#  'ADNCYC',
#  'ADNK1',
#  'EX_gam6p_e',
#  'ADNUC',
#  'ALDD2y',
#  'ALDD3y',
#  'ADPRDP',
#  'ADPT',
#  'ALLTAMH',
#  'ALLTN',
#  'ALLTNt2rpp',
#  'ALLTNtex',
#  'ADSK',
#  'ADSL1r',
#  'ADSL2r',
#  'ADSS',
#  'AGDC',
#  'ALPATE160pp',
#  'ALPATG160pp',
#  'AGM3PA',
#  'AGM3PApp',
#  'AGM3PH',
#  'AGM3Pt2pp',
#  'AGM4PA',
#  'AGM4PApp',
#  'AGM4PCP',
#  'ALR2',
#  'ALR4x',
#  'AM3PA',
#  'AM4PA',
#  'AM4PCP',
#  'AGM4PCPpp',
#  'AGM4PH',
#  'AGM4Pt2pp',
#  'AGMH',
#  'AGMT',
#  'AGMt2pp',
#  'AMPN',
#  'AGPAT120',
#  'AGPAT140',
#  'AOBUTDs',
#  'AGPAT141',
#  'AMPTASECG',
#  'AGPAT160',
#  'AGPAT161',
#  'ANHMK',
#  'AGPAT180',
#  'AP4AH',
#  'AP4AS',
#  'ASPTA',
#  'ASPabcpp',
#  'APG3PAT120',
#  'ASPt2_2pp',
#  'ASPt2_3pp',
#  'APG3PAT140',
#  'ASPt2pp_copy2',
#  'ASPtex',
#  'APG3PAT141',
#  'CDAPPA181',
#  'APG3PAT160',
#  'AST',
#  'ATHRDHr',
#  'APG3PAT161',
#  'ATPHs',
#  'ATPM',
#  'ATPS4rpp',
#  'APG3PAT180',
#  'BALAt2pp',
#  'CGLYabcpp',
#  'CHLabcpp',
#  'CHLt2pp',
#  'BETALDHy',
#  'BPNT',
#  'BSORx',
#  'APG3PAT181',
#  'BUTCT',
#  'APH120',
#  'CITL',
#  'CITt3pp',
#  'CITtex',
#  'CLIPAabctex',
#  'CLPNH120pp',
#  'CLPNH140pp',
#  'CLPNH141pp',
#  'CLPNH160pp',
#  'APH140',
#  'CAT',
#  'CLPNH161pp',
#  'CLPNH180pp',
#  'CLPNH181pp',
#  'CLPNS120pp',
#  'APH141',
#  'CLPNS140pp',
#  'CLPNS141pp',
#  'APH160',
#  'CLPNS160pp',
#  'CLPNS161pp',
#  'APH161',
#  'CLPNS180pp',
#  'CLPNS181pp',
#  'CBMD',
#  'CMPN',
#  'CBMKr',
#  'CBPS',
#  'CD2abcpp',
#  'CMtex',
#  'CMtpp',
#  'CD2t3pp',
#  'APH180',
#  'CD2tpp',
#  'CO2tex',
#  'CO2tpp',
#  'COBALT2abcpp',
#  'CDAPPA120',
#  'APH181',
#  'CDAPPA140',
#  'CDAPPA141',
#  'COBALT2t3pp',
#  'CDAPPA160',
#  'COBALT2tpp',
#  'CDAPPA161',
#  'CDAPPA180',
#  'COLIPAabctex',
#  'CPGNR1',
#  'CPGNR2',
#  'CPGNR3',
#  'CPGNUtex',
#  'CPGNUtpp',
#  'CPGNabcpp',
#  'CPGNexs',
#  'CRNDabcpp',
#  'CPGNtonex',
#  'CRNDt2rpp',
#  'ARBTNR1',
#  'CRNabcpp',
#  'ARBTNR2',
#  'DADA',
#  'DADK',
#  'CS',
#  'CSND',
#  'ARBTNR3',
#  'CSNt2pp',
#  'CTBTabcpp',
#  'DALAt2pp',
#  'DALAtex',
#  'CTBTt2rpp',
#  'DASYN120',
#  'CTPS2',
#  'ARBTNabcpp',
#  'CU1abcpp',
#  'DASYN140',
#  'DASYN141',
#  'DASYN160',
#  'CU2abcpp',
#  'DASYN161',
#  'ARBTNexs',
#  'DASYN180',
#  'DASYN181',
#  'CU2tpp',
#  'DATPHs',
#  'ARBTNtex',
#  'CUt3',
#  'DCTPD',
#  'DCYTD',
#  'CYSDS',
#  'ARBTNtonex',
#  'CYSS',
#  'ARBTNtpp',
#  'DDGLK',
#  'CYSabc2pp',
#  'CYSabcpp',
#  'CYStex',
#  'CYStpp',
#  'DGK1',
#  'CYTBD2pp',
#  'CYTBDpp',
#  'CYTBO3_4pp',
#  'CYTD',
#  'CYTDH',
#  'DHAPT',
#  'CYTDK2',
#  'DHAtex',
#  'DHAtpp',
#  'DHBS',
#  'CYTK1',
#  'CYTK2',
#  'DHBSH',
#  'ARBabcpp',
#  'D_LACt2pp',
#  'ARBt2rpp',
#  'D_LACtex',
#  'DHFR',
#  'ARBt3ipp',
#  'DHORD5',
#  'DHORTS',
#  'DMSOR1',
#  'DMSOR1pp',
#  'DMSOR2',
#  'DMSOR2pp',
#  'ARGAGMt7pp',
#  'DOGULNR',
#  'ARGDC',
#  'DOXRBCNtex',
#  'DOXRBCNtpp',
#  'EAR60x',
#  'EAR80x',
#  'ARGDCpp',
#  'DRPA',
#  'ECA4COLIPAabctex',
#  'DSBAO2',
#  'ARGORNt7pp',
#  'DSERDHr',
#  'DSERt2pp',
#  'ECOAH4',
#  'ECOAH5',
#  'DTMPK',
#  'ECOAH6',
#  'ECOAH7',
#  'ARGSL',
#  'ECOAH8',
#  'EDA',
#  'EDD',
#  'DURADx',
#  'DURIK1',
#  'ARGSS',
#  'DURIPP',
#  'DUTPDP',
#  'ENLIPAabctex',
#  'ENO',
#  'EAR100x',
#  'EAR120x',
#  'ENTCS',
#  'ENTERES',
#  'ENTERES2',
#  'ARGabcpp',
#  'EAR121x',
#  'EAR140x',
#  'ETHAAL',
#  'ETHAt2pp',
#  'ETHAtex',
#  'EAR141x',
#  'ETOHtex',
#  'ARGt3pp',
#  'EAR160x',
#  'ETOHtrpp',
#  'F6PA',
#  'EAR161x',
#  'F6PP',
#  'EAR180x',
#  'EAR181x',
#  'FA100ACPHi',
#  'FA120ACPHi',
#  'FA140ACPHi',
#  'FA141ACPHi',
#  'FA160ACPHi',
#  'FA161ACPHi',
#  'EAR40x',
#  'ASAD',
#  'FA80ACPHi',
#  'FACOAE100',
#  'FACOAE120',
#  'FACOAE140',
#  'FACOAE141',
#  'FACOAE160',
#  'FADRx',
#  'FACOAE161',
#  'FACOAE180',
#  'FACOAE181',
#  'FACOAE60',
#  'FACOAE80',
#  'FACOAL120t2pp',
#  'FACOAL140t2pp',
#  'FBA',
#  'FBA3',
#  'FBP',
#  'FACOAL141t2pp',
#  'FACOAL160t2pp',
#  'FACOAL161t2pp',
#  'FACOAL180t2pp',
#  'FACOAL181t2pp',
#  'FDH4pp',
#  'ASNN',
#  'FDH5pp',
#  'FACOAL60t2pp',
#  'ASNNpp',
#  'FEOXAMtonex',
#  'ASNS1',
#  'FEROpp',
#  'FESD1s',
#  'FE2abcpp',
#  'FE2t2pp',
#  'FE2t3pp',
#  'FESD2s',
#  'FE2tex',
#  'FESR',
#  'ASNS2',
#  'FHL',
#  'FLDR2',
#  'FLVRx',
#  'FE2tpp',
#  'FE3HOXR1',
#  'FE3HOXR2',
#  'FMNRx',
#  'FE3HOXR3',
#  'FE3HOXUtex',
#  'FORt2pp',
#  'FE3HOXUtpp',
#  'FE3HOXabcpp',
#  'ASNabcpp',
#  'FE3HOXexs',
#  'FE3HOXtonex',
#  'FORtex',
#  'FORtppi',
#  'FE3Ri',
#  'FRD2',
#  'FRD3',
#  'FE3abcpp',
#  'FE3tex',
#  'FECRMR1',
#  'FECRMR2',
#  'FECRMR3',
#  'FECRMUtex',
#  'ASNt2rpp',
#  'FECRMUtpp',
#  'FECRMabcpp',
#  'FRUpts2pp',
#  'FECRMexs',
#  'FECRMtonex',
#  'FEENTERR1',
#  'ASNtex',
#  'FTHFD',
#  'FEENTERR2',
#  'FEENTERR3',
#  'FEENTERabcpp',
#  'FEENTERexs',
#  'FTHFLi',
#  'FEENTERtex',
#  'FUM',
#  'FUMt2_2pp',
#  'FUMt2_3pp',
#  'FEENTERtonex',
#  'FEENTERtpp',
#  'FEOXAMR1',
#  'FUSAtex',
#  'FEOXAMR2',
#  'FEOXAMR3',
#  'FEOXAMUtex',
#  'FUSAtpp',
#  'G1PACT',
#  'FEOXAMUtpp',
#  'FEOXAMabcpp',
#  'FEOXAMexs',
#  'G1SAT',
#  'G2PPpp',
#  'G3PEabcpp',
#  'ASPCT',
#  'G3PGabcpp',
#  'G3PD2',
#  'G3PD5',
#  'G3PD6',
#  'G3PD7',
#  'G3PT',
#  'GHMT2r',
#  'ASPK',
#  'GK1',
#  'G5SADs',
#  'G5SD',
#  'G6PDA',
#  'G6PDH2r',
#  'GLCDpp',
#  'ASPO3',
#  'GLCNt2rpp',
#  'G6PP',
#  'ASPO4',
#  'GLCNtex',
#  'ASPO5',
#  'ASPO6',
#  'GLCabcpp',
#  'GLCptspp',
#  'GLCt2pp',
#  'ASPT',
#  'GALUi',
#  'GALabcpp',
#  'GLNS',
#  'GLNabcpp',
#  'GALt2pp',
#  'GLYCAtex',
#  'GAPD',
#  'GLU5K',
#  'GLUCYS',
#  'GLUDC',
#  'GLUDy',
#  'GLUN',
#  'GARFT',
#  'GART',
#  'GLUNpp',
#  'GLYCDx',
#  'GLUPRT',
#  'GLUR',
#  'GDPDPK',
#  'GDPMNH',
#  'GDPMNP',
#  'GLUSy',
#  'GLUTRR',
#  'GLUTRS',
#  'GLUabcpp',
#  'GDPTPDP',
#  'GF6PTA',
#  'GLUtex',
#  'GLXCL',
#  'GGGABADr',
#  'GGGABAH',
#  'GGPTRCO',
#  'GLYALDtex',
#  'GLYALDtpp',
#  'GGPTRCS',
#  'GLYAT',
#  'GLYCK2',
#  'GLYBabcpp',
#  'GLYBt2pp',
#  'GLYCL',
#  'GUAt2pp',
#  'GUAtex',
#  'GUAtpp',
#  'GLYC3Pabcpp',
#  'GLYC3Pt6pp',
#  'GLYC3Ptex',
#  'GLYCAt2rpp',
#  'H2Otex',
#  'GLYCLTDx',
#  'H2Otpp',
#  'H2SO',
#  'GLYCLTDy',
#  'H2St1pp',
#  'H2Stex',
#  'HXCT',
#  'HXPRT',
#  'HYD2pp',
#  'HYD3pp',
#  'GLYCLTtex',
#  'HYPOE',
#  'HYXNtex',
#  'HYXNtpp',
#  'Htex',
#  'HCO3E',
#  'GLYCTO2',
#  'ICDHyr',
#  'ICL',
#  'GLYCTO3',
#  'IDOND',
#  'IDOND2',
#  'IDONt2rpp',
#  'IDONtex',
#  'HEX1',
#  'HEX4',
#  'HEX7',
#  'HEXt2rpp',
#  'HG2abcpp',
#  'GLYCTO4',
#  'HG2t3pp',
#  'ILEabcpp',
#  'ILEt2rpp',
#  'IMPC',
#  'GLYCtex',
#  'IMPD',
#  'HISabcpp',
#  'GLYCtpp',
#  'HISt2rpp',
#  'GLYK',
#  'INSH',
#  'INSK',
#  'HOMt2pp',
#  'HOMtex',
#  'GLYOX',
#  'HPYRRy',
#  'GLYOX3',
#  'HSDy',
#  'HSK',
#  'HXAND',
#  'Kabcpp',
#  'LPLIPAL1E181pp',
#  'LPLIPAL1G120pp',
#  'Kt2pp',
#  'Kt3pp',
#  'LPLIPAL1G140pp',
#  'LPLIPAL1G141pp',
#  'L_LACD2_copy1',
#  'L_LACD3_copy1',
#  'LPLIPAL1G160pp',
#  'LPLIPAL1G161pp',
#  'LPLIPAL1G180pp',
#  'LPLIPAL1G181pp',
#  'LPLIPAL2A120',
#  'L_LACt2rpp',
#  'LACZ',
#  'LPLIPAL2A140',
#  'LPLIPAL2A141',
#  'LPLIPAL2A160',
#  'LPLIPAL2A161',
#  'LPLIPAL2A180',
#  'LPLIPAL2A181',
#  'LPLIPAL2ATE120',
#  'LADGMDH',
#  'LPLIPAL2ATE140',
#  'GLYtex',
#  'LPLIPAL2ATE141',
#  'LPLIPAL2ATE160',
#  'LPLIPAL2ATE161',
#  'LALDO2x',
#  'LALDO3',
#  'LALGP',
#  'LPLIPAL2ATE180',
#  'LCADi',
#  'LPLIPAL2ATE181',
#  'LPLIPAL2ATG120',
#  'LPLIPAL2ATG140',
#  'LCARR',
#  'LCARS',
#  'LCTSt3ipp',
#  'LCTStpp',
#  'LDH_D',
#  'LDH_D2',
#  'LPLIPAL2ATG141',
#  'LPLIPAL2ATG160',
#  'LPLIPAL2ATG161',
#  'LPLIPAL2ATG180',
#  'LPLIPAL2ATG181',
#  'LEUabcpp',
#  'LPLIPAL2E120',
#  'LPLIPAL2E140',
#  'LPLIPAL2E141',
#  'LEUt2rpp',
#  'LGTHL',
#  'LPLIPAL2E160',
#  'LPLIPAL2E161',
#  'LPLIPAL2E180',
#  'LPLIPAL2E181',
#  'LPLIPAL2G120',
#  'LIPAabctex',
#  'LIPOCT',
#  'LPLIPAL2G140',
#  'LPLIPAL2G141',
#  'LPLIPAL2G160',
#  'LPLIPAL2G161',
#  'LPLIPAL1A120pp',
#  'LPLIPAL2G180',
#  'LPLIPAL2G181',
#  'LSERDHr',
#  'LPLIPAL1A140pp',
#  'LPLIPAL1A141pp',
#  'LPLIPAL1A160pp',
#  'LYSabcpp',
#  'LPLIPAL1A161pp',
#  'LYSt2pp',
#  'GMPR',
#  'LYSt3pp',
#  'LPLIPAL1A180pp',
#  'LPLIPAL1A181pp',
#  'GMPS2',
#  'LPLIPAL1E120pp',
#  'LPLIPAL1E140pp',
#  'LPLIPAL1E141pp',
#  'MACPD',
#  'LPLIPAL1E160pp',
#  'LPLIPAL1E161pp',
#  'LPLIPAL1E180pp',
#  'MALS',
#  'GND',
#  'GNK',
#  'MCITD',
#  'MCITL2',
#  'MCITS',
#  'MCOATA',
#  'MALt2_2pp',
#  'MALt2_3pp',
#  'MALt3pp',
#  'MALtex',
#  'MAN1PT2',
#  'MCTP1App',
#  'MCTP1Bpp',
#  'MDDCP1pp',
#  'MDDCP4pp',
#  'MDDCP5pp',
#  'MDDEP1pp',
#  'MDDEP2pp',
#  'MDDEP3pp',
#  'MINCYCtex',
#  'MINCYCtpp',
#  'MDH',
#  'MDH2',
#  'MLDCP1App',
#  'MLDCP1Bpp',
#  'MDH3',
#  'GPDDA2',
#  'ME1',
#  'ME2',
#  'MLDCP2Bpp',
#  'MLDCP3App',
#  'MLDEP1pp',
#  'MLDEP2pp',
#  'MELIBt2pp',
#  'MELIBt3ipp',
#  'MLTG3',
#  'GPDDA2pp',
#  'MLTG4',
#  'MLTG5',
#  'MLTGY1pp',
#  'METOX1s',
#  'MLTGY2pp',
#  'MLTGY3pp',
#  'METOX2s',
#  'GPDDA3pp',
#  'MLTP1',
#  'MLTP2',
#  'MLTP3',
#  'MMCD',
#  'MMM',
#  'METSOXR1',
#  'METSOXR2',
#  'MN2t3pp',
#  'MN2tpp',
#  'GPDDA4',
#  'MG2t3_2pp',
#  'MN6PP',
#  'MNt2pp',
#  'MG2tpp',
#  'MG2uabcpp',
#  'MGSA',
#  'GPDDA4pp',
#  'MICITDr_copy1',
#  'MOX',
#  'OCBT',
#  'MPTG',
#  'NADDP',
#  'NADH10',
#  'MSAR',
#  'NADH16pp',
#  'GRXR',
#  'NADH17pp',
#  'NADH18pp',
#  ...]

# %%
l_one= len(D)
l_flat= len(flat)
l_diff= len(diff)

# %%
flat
# Out:
# ['EX_cpgn_un_e',
#  'EX_cu_e',
#  'EX_gtp_e',
#  'EX_acgal1p_e',
#  'EX_lys__L_e',
#  'EX_arbtn_e',
#  'EX_minohp_e',
#  'EX_dopa_e',
#  'EX_xmp_e',
#  'EX_peamn_e',
#  'EX_enter_e',
#  'EX_tym_e',
#  'EX_tyrp_e',
#  '2DGULRGy',
#  '2DGULRx',
#  '2DGULRy',
#  'EX_fe3hox_un_e',
#  'EX_fecrm_un_e',
#  'EX_feoxam_un_e',
#  'ABUTt2pp',
#  'ACACT1r',
#  'ACACT2r',
#  'ACACT3r',
#  'ACACT4r',
#  'ACACT5r',
#  'ACACT6r',
#  'ACACT7r',
#  'ACACT8r_copy1',
#  'ACCOAL',
#  'ACLS',
#  'ACS',
#  'ACt2rpp',
#  'ACt4pp',
#  'ALATA_L',
#  'ALAt2pp_copy1',
#  'ALAt2pp_copy2',
#  'ALAt4pp',
#  'ADK1',
#  'ADK3',
#  'ALDD19xr_copy1',
#  'AMALT2',
#  'AMALT3',
#  'AMALT4',
#  'ASPt2pp_copy1',
#  'BETALDHx',
#  'BSORy',
#  'CA2t3pp',
#  'CAt6pp',
#  'CRNCAL2',
#  'CRNt2rpp',
#  'CRNt8pp',
#  'CTBTCAL2',
#  'CTECOAI6_copy1',
#  'CTECOAI7_copy1',
#  'CTECOAI8_copy1',
#  'CU1Opp',
#  'DHAD1',
#  'DAAD',
#  'DHNPA2r_copy1',
#  'DHORD2',
#  'DHORDfum',
#  'DKGLCNR2x',
#  'DKGLCNR2y',
#  'DMPPS',
#  'EAR40y',
#  'EAR60y',
#  'EAR80y',
#  'DSBAO1',
#  'EAR100y',
#  'EAR120y',
#  'EAR121y',
#  'EAR140y',
#  'EAR141y',
#  'EAR160y',
#  'EAR161y',
#  'EAR180y',
#  'EAR181y',
#  'FADRx2',
#  'FLVR',
#  'FMNRx2',
#  'FOMETRi',
#  'GLBRAN2',
#  'GLCP',
#  'GLCP2',
#  'GLCS1',
#  'GLCtex_copy1',
#  'GLCtex_copy2',
#  'GLDBRAN2',
#  'GLGC',
#  'GLUABUTt7pp',
#  'GLUt2rpp',
#  'GLUt4pp',
#  'GLYCK',
#  'GLYCLTt2rpp',
#  'GLYCLTt4pp',
#  'HACD1',
#  'HYD1pp',
#  'HACD2',
#  'HACD3',
#  'HACD4',
#  'HACD5',
#  'HACD6',
#  'HACD7',
#  'HACD8',
#  'ICHORS_copy1',
#  'ICHORS_copy2',
#  'INDOLEt2pp',
#  'INDOLEt2rpp',
#  'IPDPS',
#  'HPYRI',
#  'HPYRRx',
#  'KARA1',
#  'KAS14',
#  'KAS15',
#  'GLYt2pp_copy1',
#  'GLYt2pp_copy2',
#  'GLYt4pp',
#  'L_LACtex_copy1',
#  'MDDCP3pp',
#  'MECDPDH5',
#  'MLDCP2App',
#  'NO3R2pp',
#  'NAt3pp',
#  'NDPK1',
#  'NODOy',
#  'NHFRBO',
#  'NMNt7pp',
#  'OCTNLL',
#  'PDX5PO2',
#  'PDX5POi',
#  'PROt2rpp',
#  'PROt4pp',
#  'QMO3',
#  'R15BPK',
#  'R1PK',
#  'SSALx',
#  'SERt2rpp',
#  'SERt4pp',
#  'THFAT',
#  'THRA',
#  'THRD',
#  'TRPS1',
#  'TRSARr',
#  'URAt2pp_copy1',
#  'URAt2pp_copy2',
#  'VPAMTr_copy1',
#  'VALTA',
#  'L_LACtex_copy2',
#  'MICITDr_copy2',
#  'NPHS',
#  'CTECOAI8_copy2',
#  'CTECOAI6_copy2',
#  'VPAMTr_copy2',
#  'PPCSCT',
#  '2DGLCNRy',
#  'ALDD19xr_copy2',
#  'DHNPA2r_copy2',
#  'HACD1i',
#  'HACD2i',
#  'HACD3i',
#  'HACD4i',
#  'HACD5i',
#  'DARBt2rpp_copy1',
#  'HACD6i',
#  'HACD7i',
#  'DARBt2rpp_copy2',
#  'HACD8i',
#  'CTECOAI7_copy2',
#  'KAT1',
#  'ACACT11',
#  'ACACT8',
#  'ACACT13',
#  'ACACT10',
#  'ACACT9',
#  'ACACT12',
#  'ACACT8r_copy2',
#  'DOGULND']
